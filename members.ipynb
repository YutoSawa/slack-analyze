# %%
token = "xoxp-628846171825-637360000198-684571925680-a66e11b69c4fe517876ff564478e518f"
channles_id = "https://slack.com/api/channels.list"
users=  "https://slack.com/api/users.list"
talk_history = "https://slack.com/api/channels.history?count=1000&token=" + token + "&channel="

# %%
channel_json
# Out:
# {'ok': True,
#  'channels': [{'id': 'CJCN9CH43',
#    'name': '04-1-ニュース-話題',
#    'is_channel': True,
#    'created': 1557922672,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '04-1-ﾆｭｰｽ-話題',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJKFAPBCJ',
#     'UJRAL005U',
#     'UJRDMQSAD',
#     'UKEMYD9R8',
#     'UKFLR3VHR',
#     'UKFMDBUV9',
#     'UKFPM8H35',
#     'UKG6BDAPL',
#     'UKHMWSMBL',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKPRX1CCW',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT3NHRM3',
#     'UKT5BQD3P',
#     'UKT5WSVCY',
#     'UKU6PP3J5',
#     'UKX7JQRPY',
#     'UKY4VFB5E',
#     'UL02Y5QAY',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UL2TY2ERL',
#     'ULJ74QZJM',
#     'ULKPET3UK',
#     'ULM6FBU11',
#     'ULQ3D7T2Q',
#     'ULQU5MHA8',
#     'UM9G63GUR',
#     'UMBPQ87PB',
#     'UMC518ER0',
#     'UMEBUFHJP',
#     'UMFGQHD46',
#     'UMG0947NY',
#     'UMKAYGVH6',
#     'UMLHAREMC',
#     'UMLJU57L6',
#     'UMNHH3U9G',
#     'UMQ7CDJUR',
#     'UMTLWHVP1',
#     'UMTMKBB1Q',
#     'UMY9V0N49',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UNGA09ANL',
#     'UNJD36PFG',
#     'UNJF7RNP8',
#     'UNJFZNZ6J',
#     'UNKM5GP8W',
#     'UP0M4359C',
#     'UP2AX92SE',
#     'UP3NJELGJ',
#     'UP5KY3DFD',
#     'UPAD4C0B0',
#     'UPBV44H6H',
#     'UPCS9LZKR',
#     'UPDRPAHN2',
#     'UPF4T5DE1',
#     'UPQ6N68BG',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ00K3VNZ',
#     'UQ00KD621',
#     'UQ0KGGPK7',
#     'UQ7QAPL6S',
#     'UQ8NVHJFJ',
#     'UQGMHCCJ2'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['04-1-ニュース_話題',
#     '04_1_ニュース_話題',
#     '04_2_ニュース',
#     '04_ニュース',
#     '03_ニュース_話題のトピック',
#     '03_1_ニュース_話題のトピック'],
#    'num_members': 70},
#   {'id': 'CJCNV9LG2',
#    'name': '03-1-質問',
#    'is_channel': True,
#    'created': 1557922422,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '03-1-質問',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJKFAPBCJ',
#     'UJRAL005U',
#     'UJRDMQSAD',
#     'UKEMYD9R8',
#     'UKFLR3VHR',
#     'UKFMDBUV9',
#     'UKFPM8H35',
#     'UKG6BDAPL',
#     'UKHMWSMBL',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKPRX1CCW',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT3NHRM3',
#     'UKT5BQD3P',
#     'UKT5WSVCY',
#     'UKU6PP3J5',
#     'UKX7JQRPY',
#     'UKY4VFB5E',
#     'UL02Y5QAY',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UL2TY2ERL',
#     'ULJ74QZJM',
#     'ULKPET3UK',
#     'ULM6FBU11',
#     'ULQ3D7T2Q',
#     'ULQU5MHA8',
#     'UM9G63GUR',
#     'UMBPQ87PB',
#     'UMC518ER0',
#     'UMEBUFHJP',
#     'UMFGQHD46',
#     'UMG0947NY',
#     'UMKAYGVH6',
#     'UMLHAREMC',
#     'UMLJU57L6',
#     'UMNHH3U9G',
#     'UMQ7CDJUR',
#     'UMTLWHVP1',
#     'UMTMKBB1Q',
#     'UMY9V0N49',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UNGA09ANL',
#     'UNJD36PFG',
#     'UNJF7RNP8',
#     'UNJFZNZ6J',
#     'UNKM5GP8W',
#     'UP0M4359C',
#     'UP2AX92SE',
#     'UP3NJELGJ',
#     'UP5KY3DFD',
#     'UPAD4C0B0',
#     'UPBV44H6H',
#     'UPCS9LZKR',
#     'UPDRPAHN2',
#     'UPF4T5DE1',
#     'UPQ6N68BG',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ00K3VNZ',
#     'UQ00KD621',
#     'UQ0KGGPK7',
#     'UQ7QAPL6S',
#     'UQ8NVHJFJ',
#     'UQGMHCCJ2'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['03_1_質問', '03_1_分析に関する質問', '02_3_分析に関する質問'],
#    'num_members': 70},
#   {'id': 'CJCRX6MFV',
#    'name': '06-1-イベント',
#    'is_channel': True,
#    'created': 1557929037,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '06-1-ｲﾍﾞﾝﾄ',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U',
#     'UKPAM2942',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKU6PP3J5',
#     'UKY4VFB5E',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'ULKPET3UK',
#     'ULQ3D7T2Q',
#     'UMC518ER0',
#     'UMG0947NY',
#     'UMTMKBB1Q',
#     'UMY9V0N49',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UPR6BE9S6',
#     'UQ8NVHJFJ'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['06_1_イベント'],
#    'num_members': 20},
#   {'id': 'CJHULABR7',
#    'name': '02-2-おススメ書籍',
#    'is_channel': True,
#    'created': 1557928579,
#    'is_archived': True,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '02-2-おｽｽﾒ書籍',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': False,
#    'is_private': False,
#    'is_mpim': False,
#    'members': [],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['02_2_おススメ書籍'],
#    'num_members': 0},
#   {'id': 'CJHUWCSN5',
#    'name': '05-3-結果報告',
#    'is_channel': True,
#    'created': 1557928985,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '05-3-結果報告',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U',
#     'UKFLR3VHR',
#     'UKPAM2942',
#     'UKQHU14D9',
#     'UKT5BQD3P',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'ULJ74QZJM',
#     'UMG0947NY',
#     'UMQ7CDJUR',
#     'UN1V4ELKV',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ8NVHJFJ'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['05_3_結果報告'],
#    'num_members': 15},
#   {'id': 'CJHUX04M7',
#    'name': '03-2-ディスカッション',
#    'is_channel': True,
#    'created': 1557929005,
#    'is_archived': True,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '03-2-ﾃﾞｨｽｶｯｼｮﾝ',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': False,
#    'is_private': False,
#    'is_mpim': False,
#    'members': [],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['03_2_ディスカッション'],
#    'num_members': 0},
#   {'id': 'CJNKJ8JKW',
#    'name': 'general',
#    'is_channel': True,
#    'created': 1557846999,
#    'is_archived': False,
#    'is_general': True,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': 'general',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJKFAPBCJ',
#     'UJRAL005U',
#     'UJRDMQSAD',
#     'UKEMYD9R8',
#     'UKFLR3VHR',
#     'UKFMDBUV9',
#     'UKFPM8H35',
#     'UKG6BDAPL',
#     'UKHMWSMBL',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKPRX1CCW',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT3NHRM3',
#     'UKT5BQD3P',
#     'UKT5WSVCY',
#     'UKU6PP3J5',
#     'UKX7JQRPY',
#     'UKY4VFB5E',
#     'UL02Y5QAY',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UL2TY2ERL',
#     'ULJ74QZJM',
#     'ULKPET3UK',
#     'ULM6FBU11',
#     'ULQ3D7T2Q',
#     'ULQU5MHA8',
#     'UM9G63GUR',
#     'UMBPQ87PB',
#     'UMC518ER0',
#     'UMEBUFHJP',
#     'UMFGQHD46',
#     'UMG0947NY',
#     'UMKAYGVH6',
#     'UMLHAREMC',
#     'UMLJU57L6',
#     'UMNHH3U9G',
#     'UMQ7CDJUR',
#     'UMTLWHVP1',
#     'UMTMKBB1Q',
#     'UMY9V0N49',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UNGA09ANL',
#     'UNJD36PFG',
#     'UNJF7RNP8',
#     'UNJFZNZ6J',
#     'UNKM5GP8W',
#     'UP0M4359C',
#     'UP2AX92SE',
#     'UP3NJELGJ',
#     'UP5KY3DFD',
#     'UPAD4C0B0',
#     'UPBV44H6H',
#     'UPCS9LZKR',
#     'UPDRPAHN2',
#     'UPF4T5DE1',
#     'UPQ6N68BG',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ00K3VNZ',
#     'UQ00KD621',
#     'UQ0KGGPK7',
#     'UQ7QAPL6S',
#     'UQ8NVHJFJ',
#     'UQGMHCCJ2'],
#    'topic': {'value': '全社的なアナウンスと業務関連の事項',
#     'creator': 'UJRAL005U',
#     'last_set': 1557846999},
#    'purpose': {'value': 'このチャンネルはワークスペース全体のコミュニケーションと社内アナウンス用です。全メンバーがこのチャンネルに参加しています。',
#     'creator': 'UJRAL005U',
#     'last_set': 1557846999},
#    'previous_names': [],
#    'num_members': 70},
#   {'id': 'CJP4LUU2H',
#    'name': 'random',
#    'is_channel': True,
#    'created': 1557846999,
#    'is_archived': True,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': 'random',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': False,
#    'is_private': False,
#    'is_mpim': False,
#    'members': [],
#    'topic': {'value': '仕事に関係ない雑談と給湯室でのおしゃべり',
#     'creator': 'UJRAL005U',
#     'last_set': 1557846999},
#    'purpose': {'value': '仕事に関係ないペチャクチャ、ワイワイ、ざわざわといったチャンネルは、仕事に関係したチャンネルとは別にしておいたほうがいいです。',
#     'creator': 'UJRAL005U',
#     'last_set': 1557846999},
#    'previous_names': [],
#    'num_members': 0},
#   {'id': 'CJP5VF13J',
#    'name': '00-1-はじめに',
#    'is_channel': True,
#    'created': 1557847197,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '00-1-はじめに',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJKFAPBCJ',
#     'UJRAL005U',
#     'UJRDMQSAD',
#     'UKEMYD9R8',
#     'UKFLR3VHR',
#     'UKFMDBUV9',
#     'UKFPM8H35',
#     'UKG6BDAPL',
#     'UKHMWSMBL',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKPRX1CCW',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT3NHRM3',
#     'UKT5BQD3P',
#     'UKT5WSVCY',
#     'UKU6PP3J5',
#     'UKX7JQRPY',
#     'UKY4VFB5E',
#     'UL02Y5QAY',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UL2TY2ERL',
#     'ULJ74QZJM',
#     'ULKPET3UK',
#     'ULM6FBU11',
#     'ULQ3D7T2Q',
#     'ULQU5MHA8',
#     'UM9G63GUR',
#     'UMBPQ87PB',
#     'UMC518ER0',
#     'UMEBUFHJP',
#     'UMFGQHD46',
#     'UMG0947NY',
#     'UMKAYGVH6',
#     'UMLHAREMC',
#     'UMLJU57L6',
#     'UMNHH3U9G',
#     'UMQ7CDJUR',
#     'UMTLWHVP1',
#     'UMTMKBB1Q',
#     'UMY9V0N49',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UNGA09ANL',
#     'UNJD36PFG',
#     'UNJF7RNP8',
#     'UNJFZNZ6J',
#     'UNKM5GP8W',
#     'UP0M4359C',
#     'UP2AX92SE',
#     'UP3NJELGJ',
#     'UP5KY3DFD',
#     'UPAD4C0B0',
#     'UPBV44H6H',
#     'UPCS9LZKR',
#     'UPDRPAHN2',
#     'UPF4T5DE1',
#     'UPQ6N68BG',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ00K3VNZ',
#     'UQ00KD621',
#     'UQ0KGGPK7',
#     'UQ7QAPL6S',
#     'UQ8NVHJFJ',
#     'UQGMHCCJ2'],
#    'topic': {'value': '', 'creator': 'UJRAL005U', 'last_set': 1557923662},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['00_1_はじめに',
#     '00_はじめに',
#     '000_はじめに',
#     '00_はじめに',
#     '00_1_はじめに',
#     '00_1_アナウンス_はじめに'],
#    'num_members': 70},
#   {'id': 'CJP6483K2',
#    'name': '01-1-自己紹介',
#    'is_channel': True,
#    'created': 1557847579,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '01-1-自己紹介',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJKFAPBCJ',
#     'UJRAL005U',
#     'UJRDMQSAD',
#     'UKEMYD9R8',
#     'UKFLR3VHR',
#     'UKFMDBUV9',
#     'UKFPM8H35',
#     'UKG6BDAPL',
#     'UKHMWSMBL',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKPRX1CCW',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT3NHRM3',
#     'UKT5BQD3P',
#     'UKT5WSVCY',
#     'UKU6PP3J5',
#     'UKX7JQRPY',
#     'UKY4VFB5E',
#     'UL02Y5QAY',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UL2TY2ERL',
#     'ULJ74QZJM',
#     'ULKPET3UK',
#     'ULM6FBU11',
#     'ULQ3D7T2Q',
#     'ULQU5MHA8',
#     'UM9G63GUR',
#     'UMBPQ87PB',
#     'UMC518ER0',
#     'UMEBUFHJP',
#     'UMFGQHD46',
#     'UMG0947NY',
#     'UMKAYGVH6',
#     'UMLHAREMC',
#     'UMLJU57L6',
#     'UMNHH3U9G',
#     'UMQ7CDJUR',
#     'UMTLWHVP1',
#     'UMTMKBB1Q',
#     'UMY9V0N49',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UNGA09ANL',
#     'UNJD36PFG',
#     'UNJF7RNP8',
#     'UNJFZNZ6J',
#     'UNKM5GP8W',
#     'UP0M4359C',
#     'UP2AX92SE',
#     'UP3NJELGJ',
#     'UP5KY3DFD',
#     'UPAD4C0B0',
#     'UPBV44H6H',
#     'UPCS9LZKR',
#     'UPDRPAHN2',
#     'UPF4T5DE1',
#     'UPQ6N68BG',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ00K3VNZ',
#     'UQ00KD621',
#     'UQ0KGGPK7',
#     'UQ7QAPL6S',
#     'UQ8NVHJFJ',
#     'UQGMHCCJ2'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['01_1_自己紹介', '02_1_自己紹介'],
#    'num_members': 70},
#   {'id': 'CJPPRCKBN',
#    'name': '08-1-教材',
#    'is_channel': True,
#    'created': 1557929235,
#    'is_archived': True,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '08-1-教材',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': False,
#    'is_private': False,
#    'is_mpim': False,
#    'members': [],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['08-1-ディープラーニング入門',
#     '08_1_ディープラーニング入門',
#     '08_1_pfnチュートリアル'],
#    'num_members': 0},
#   {'id': 'CJQ8QNGBF',
#    'name': '07-01-企画-slack分析',
#    'is_channel': True,
#    'created': 1557929103,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-01-企画-slack分析',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U',
#     'UKFLR3VHR',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT3NHRM3',
#     'UKU6PP3J5',
#     'UKY4VFB5E',
#     'UL02Y5QAY',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UL2TY2ERL',
#     'ULJ74QZJM',
#     'ULKPET3UK',
#     'ULQ3D7T2Q',
#     'ULQU5MHA8',
#     'UMC518ER0',
#     'UMFGQHD46',
#     'UMQ7CDJUR',
#     'UMTMKBB1Q',
#     'UMY9V0N49',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UNJD36PFG',
#     'UNKM5GP8W',
#     'UP3NJELGJ',
#     'UPAD4C0B0',
#     'UPSFL6VAP',
#     'UQ7QAPL6S',
#     'UQ8NVHJFJ'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-1-企画-slack分析',
#     '07-1-演習-ワークショップ',
#     '07_1_演習_ワークショップ',
#     '07_演習_ワークショップ'],
#    'num_members': 33},
#   {'id': 'CJQ9QFFEC',
#    'name': '05-1-目標設定',
#    'is_channel': True,
#    'created': 1557928951,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '05-1-目標設定',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJKFAPBCJ',
#     'UJRAL005U',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT5BQD3P',
#     'UL08YKGLU',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UL2TY2ERL',
#     'ULJ74QZJM',
#     'ULKPET3UK',
#     'ULM6FBU11',
#     'ULQ3D7T2Q',
#     'UMC518ER0',
#     'UMG0947NY',
#     'UMQ7CDJUR',
#     'UN0HCK74M',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UP3NJELGJ',
#     'UPAD4C0B0',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ7QAPL6S',
#     'UQ8NVHJFJ'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['05_1_目標設定'],
#    'num_members': 27},
#   {'id': 'CJQ9QU6GY',
#    'name': '05-2-お悩み相談',
#    'is_channel': True,
#    'created': 1557928969,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '05-2-お悩み相談',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U',
#     'UKPAM2942',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UMG0947NY',
#     'UMQ7CDJUR',
#     'UMTMKBB1Q',
#     'UN1V4ELKV',
#     'UNFAV5EDB',
#     'UP3NJELGJ',
#     'UPR6BE9S6',
#     'UPSFL6VAP',
#     'UQ8NVHJFJ'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['05_2_お悩み相談'],
#    'num_members': 15},
#   {'id': 'CJQFFTF5J',
#    'name': '10-3-案件相談',
#    'is_channel': True,
#    'created': 1557972790,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '10-3-案件相談',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U',
#     'UKPAM2942',
#     'UKQHU14D9',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'ULQ3D7T2Q',
#     'UN1V4ELKV',
#     'UPR6BE9S6',
#     'UQ8NVHJFJ'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['10_3_案件相談', '10_3_案件に関するご相談'],
#    'num_members': 9},
#   {'id': 'CJR0J0N69',
#    'name': '10-2-求職',
#    'is_channel': True,
#    'created': 1557972765,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '10-2-求職',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U',
#     'UKFLR3VHR',
#     'UKQHU14D9',
#     'UL0NZCCMT',
#     'UL2TSDLG6',
#     'UMY9V0N49',
#     'UN1V4ELKV',
#     'UQ8NVHJFJ'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['10_2_求職'],
#    'num_members': 8},
#   {'id': 'CJR0XDM1D',
#    'name': '02-1-雑談',
#    'is_channel': True,
#    'created': 1557847450,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '02-1-雑談',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJKFAPBCJ',
#     'UJRAL005U',
#     'UJRDMQSAD',
#     'UKEMYD9R8',
#     'UKFLR3VHR',
#     'UKFMDBUV9',
#     'UKFPM8H35',
#     'UKG6BDAPL',
#     'UKHMWSMBL',
#     'UKPAM2942',
#     'UKPCQAQLA',
#     'UKPRX1CCW',
#     'UKQHU14D9',
#     'UKT3G90U8',
#     'UKT3NHRM3',
#     'UKT5BQD3P',
#     'UKT5WSVCY',
#     'UKU6PP3J5',
#     'UKX7JQRPY',
#     'UKY4VFB5E',
#     'UL02Y5QAY',
#     'UL08YKGLU',
#     'UL0NZCCMT'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['02_1_雑談', '02_2_雑談', '02_1_雑談', '02_雑談'],
#    'num_members': 70},
#   {'id': 'CJRAUJTFY',
#    'name': '00-2-運営からのアナウンス',
#    'is_channel': True,
#    'created': 1557847374,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '00-2-運営からのｱﾅｳﾝｽ',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['00_2_運営からのアナウンス',
#     '00_1_運営からのアナウンス',
#     '002_運営からのアナウンス',
#     '001_運営からのアナウンス',
#     '01_運営からのアナウンス',
#     '00_3_運営からのアナウンス',
#     '00_1_運営からのアナウンス',
#     '01_1_運営からのアナウンス'],
#    'num_members': 70},
#   {'id': 'CJS0Y131D',
#    'name': '00-3-ギルドに関する質問',
#    'is_channel': True,
#    'created': 1557922450,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '00-3-ｷﾞﾙﾄﾞに関する質問',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['00_3_ギルドに関する質問', '02_4_ギルドに関する質問', '02_4_分析に関する質問'],
#    'num_members': 70},
#   {'id': 'CJSF0G214',
#    'name': '09-1-リクエスト',
#    'is_channel': True,
#    'created': 1557929569,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '09-1-ﾘｸｴｽﾄ',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['09_1_リクエスト'],
#    'num_members': 8},
#   {'id': 'CJT6G95EJ',
#    'name': '10-1-求人',
#    'is_channel': True,
#    'created': 1557972701,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '10-1-求人',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['10_1_求人', '10_求人'],
#    'num_members': 18},
#   {'id': 'CL1DPQDJP',
#    'name': '07-02-強化学習',
#    'is_channel': True,
#    'created': 1562936948,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-02-強化学習',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-2-強化学習'],
#    'num_members': 12},
#   {'id': 'CL4V80D40',
#    'name': '07-04-ボードゲーム部',
#    'is_channel': True,
#    'created': 1562240168,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-04-ﾎﾞｰﾄﾞｹﾞｰﾑ部',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': 'UKFLR3VHR', 'last_set': 1562305200},
#    'purpose': {'value': 'ギルドのメンバーで構成し活動するボードギルドボードゲーム部は、ゲームを通して交流したり、ゲームをプレイ＆そのプレイデータを分析しながら勉強したりする',
#     'creator': 'UKFLR3VHR',
#     'last_set': 1562305284},
#    'previous_names': ['07-4-ボードゲーム部',
#     '07-3-ボードゲーム部',
#     '02-ボードゲーム部',
#     '06-ボードゲーム部',
#     '06-ボ'],
#    'num_members': 20},
#   {'id': 'CLEQVN58F',
#    'name': '08-1-scrapbox更新通知',
#    'is_channel': True,
#    'created': 1562943020,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '08-1-scrapbox更新通知',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['11-1-scrapbox更新通知',
#     '11-1-自習室-scrapbox',
#     '11-1-scrap-box'],
#    'num_members': 6},
#   {'id': 'CLF0R3ULE',
#    'name': '07-03-機械学習関連数学-再入門',
#    'is_channel': True,
#    'created': 1562937742,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-03-機械学習関連数学-再入門',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '<https://scrapbox.io/dl-guild/%E6%95%B0%E5%AD%A6%E5%9F%BA%E7%A4%8E%E8%AB%96%E5%8B%89%E5%BC%B7%E4%BC%9A>',
#     'creator': 'UL0NZCCMT',
#     'last_set': 1563352010},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-03-機械学習関連数学-再学習',
#     '07-03-企画-数学基礎論_圏論',
#     '07-3-企画-数学基礎論_圏論',
#     '07-3-企画-数学基礎論圏論'],
#    'num_members': 12},
#   {'id': 'CLMQW3SAJ',
#    'name': '03-3-セキュリティ-ジョージア移住',
#    'is_channel': True,
#    'created': 1563526994,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '03-3-ｾｷｭﾘﾃｨ-ｼﾞｮｰｼﾞｱ移住',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': 'ジョージアでリモートワークしたい！！',
#     'creator': 'UJRAL005U',
#     'last_set': 1563527091},
#    'purpose': {'value': 'ジョージアにいながらデータサイエンスの仕事が出来るようなセキュリティを担保するには、どうすればいいのか？',
#     'creator': 'UJRAL005U',
#     'last_set': 1563527091},
#    'previous_names': ['03-5-セキュリティ-ジョージア移住',
#     '07-5-セキュリティ-ジョージア移住',
#     '07-5-セキュリティ'],
#    'num_members': 9},
#   {'id': 'CLURTCVT5',
#    'name': '07-05-ml-study-jam',
#    'is_channel': True,
#    'created': 1565265839,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-05-ml-study-jam',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-5-ml-study-jam'],
#    'num_members': 30},
#   {'id': 'CM0GYR08P',
#    'name': '02-2-雑談-技術-分析',
#    'is_channel': True,
#    'created': 1564642755,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '02-2-雑談-技術-分析',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '技術や分析に関する雑談チャンネル',
#     'creator': 'UJRAL005U',
#     'last_set': 1564642756},
#    'previous_names': [],
#    'num_members': 70},
#   {'id': 'CMFEEDM40',
#    'name': '07-06-グロースハック_マーケティング',
#    'is_channel': True,
#    'created': 1566011653,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-06-ｸﾞﾛｰｽﾊｯｸ_ﾏｰｹﾃｨﾝｸﾞ',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': 'データラーニング ギルドのマーケティング、グロースハックを教材として、実践的な技術を学ぶ',
#     'creator': 'UJRAL005U',
#     'last_set': 1566011654},
#    'previous_names': ['07-6-グロースハック_マーケティング'],
#    'num_members': 22},
#   {'id': 'CN2V5HFG8',
#    'name': '05-2-進捗報告',
#    'is_channel': True,
#    'created': 1567755377,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '05-2-進捗報告',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '目標設定で設定したことに関する進捗を報告する',
#     'creator': 'UJRAL005U',
#     'last_set': 1567755378},
#    'previous_names': ['07-2-進捗報告', '07-02-進捗報告'],
#    'num_members': 11},
#   {'id': 'CNHK3LY3F',
#    'name': '06-2-イベント-9月',
#    'is_channel': True,
#    'created': 1568875592,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UKPRX1CCW',
#    'name_normalized': '06-2-ｲﾍﾞﾝﾄ-9月',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '9月のオフラインイベント',
#     'creator': 'UKPRX1CCW',
#     'last_set': 1568875592},
#    'previous_names': [],
#    'num_members': 12},
#   {'id': 'CNKV8CVN0',
#    'name': '07-01-slack分析コンペ-チーム2',
#    'is_channel': True,
#    'created': 1569052815,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-01-slack分析ｺﾝﾍﾟ-ﾁｰﾑ2',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-1-slack分析コンペ-チーム2'],
#    'num_members': 7},
#   {'id': 'CNLDM3NJ1',
#    'name': '07-01-slack分析コンペ-チーム3',
#    'is_channel': True,
#    'created': 1569052830,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-01-slack分析ｺﾝﾍﾟ-ﾁｰﾑ3',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-1-slack分析コンペ-チーム3'],
#    'num_members': 7},
#   {'id': 'CNN9B279D',
#    'name': '07-01-slack分析コンペ-チーム1',
#    'is_channel': True,
#    'created': 1569052746,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-01-slack分析ｺﾝﾍﾟ-ﾁｰﾑ1',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-1-slack分析コンペ-チーム1'],
#    'num_members': 7},
#   {'id': 'CNUU4QLGH',
#    'name': '07-08-楽音調教',
#    'is_channel': True,
#    'created': 1570149740,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-08-楽音調教',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': 'このチャンネルは、09/26開催の『データ分析者としての学習ロードマップ(初学者・初級者編)』にて、私吉村が下記リンクを発表させて頂いたのがトリガーとなり、10/03開催のオンライン説明会&amp;懇親会にて、DLG代表の村上氏より研究テーマとしてみてはどうかとのご意見を頂き、チャンネル立ち上げの運びとなりました。\n\n【トリガーとなった発表の資料】\n<https://speakerdeck.com/brainbrown/ji-jie-xue-xi-deyatutemitaishi>',
#     'creator': 'UN0HCK74M',
#     'last_set': 1570285243},
#    'previous_names': ['07-8-楽音調教'],
#    'num_members': 8},
#   {'id': 'CNX7CKQJ1',
#    'name': '07-07-仕事の説明書輪読会',
#    'is_channel': True,
#    'created': 1569920793,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-07-仕事の説明書輪読会',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-7-仕事の説明書輪読会'],
#    'num_members': 15},
#   {'id': 'CP44WSEQY',
#    'name': '07-09-note執筆グループ',
#    'is_channel': True,
#    'created': 1570452169,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-09-note執筆ｸﾞﾙｰﾌﾟ',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': ['07-9-note執筆グループ'],
#    'num_members': 7},
#   {'id': 'CP8TDBBA7',
#    'name': '06-4-イベント-11月',
#    'is_channel': True,
#    'created': 1571631601,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UKPRX1CCW',
#    'name_normalized': '06-4-ｲﾍﾞﾝﾄ-11月',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '11/5のイベント当日アナウンスをするチャンネル',
#     'creator': 'UKPRX1CCW',
#     'last_set': 1571631601},
#    'previous_names': [],
#    'num_members': 20},
#   {'id': 'CPAQQRF4N',
#    'name': '06-3-イベント-10月',
#    'is_channel': True,
#    'created': 1570708326,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UKPRX1CCW',
#    'name_normalized': '06-3-ｲﾍﾞﾝﾄ-10月',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '10月17日のイベントに関してアナウンスするチャンネル',
#     'creator': 'UKPRX1CCW',
#     'last_set': 1570708327},
#    'previous_names': [],
#    'num_members': 15},
#   {'id': 'CPDSGJRQF',
#    'name': '99-kaggle-beginner',
#    'is_channel': True,
#    'created': 1571031296,
#    'is_archived': True,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '99-kaggle-beginner',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': False,
#    'is_private': False,
#    'is_mpim': False,
#    'members': [],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': [],
#    'num_members': 0},
#   {'id': 'CPVAA91PA',
#    'name': '02-3-練習問題',
#    'is_channel': True,
#    'created': 1572252755,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '02-3-練習問題',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': [],
#    'num_members': 11},
#   {'id': 'CQ9JPC406',
#    'name': '07-10-プロフィール共有サービス開発',
#    'is_channel': True,
#    'created': 1573030364,
#    'is_archived': False,
#    'is_general': False,
#    'unlinked': 0,
#    'creator': 'UJRAL005U',
#    'name_normalized': '07-10-ﾌﾟﾛﾌｨｰﾙ共有ｻｰﾋﾞｽ開発',
#    'is_shared': False,
#    'is_org_shared': False,
#    'is_member': True,
#    'is_private': False,
#    'is_mpim': False,
#    'members': ['UJRAL005U'],
#    'topic': {'value': '', 'creator': '', 'last_set': 0},
#    'purpose': {'value': '', 'creator': '', 'last_set': 0},
#    'previous_names': [],
#    'num_members': 5}],
#  'response_metadata': {'next_cursor': ''}}

# %%
payload = {
     "token":token
}

channel_response = requests.get(channles_id, params=payload)
channel_json = channel_response.json()
channel_df = pd.DataFrame(data=channel_json["channels"][0]["members"])

# %%
channel_df
# Out:
#             0
# 0   UJKFAPBCJ
# 1   UJRAL005U
# 2   UJRDMQSAD
# 3   UKEMYD9R8
# 4   UKFLR3VHR
# ..        ...
# 65  UQ00KD621
# 66  UQ0KGGPK7
# 67  UQ7QAPL6S
# 68  UQ8NVHJFJ
# 69  UQGMHCCJ2
#
# [70 rows x 1 columns]
